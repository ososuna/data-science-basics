# %% [markdown]
# # Measures of Central Tendency
#
# ## 📐 Mean
# The **mean** (or arithmetic average) of a set of $n$ numbers $x_1, x_2, \dots, x_n$ is defined as:
# $$
# \text{mean} = \bar{x} = \frac{1}{n} \sum_{i=1}^{n} x_i
# $$
#
# ---
#
# ## 🔗 Median
# The **median** is the middle value of the ordered data set.
#
# - If $n$ (the number of observations) is **odd**, the median is:
# $$
# \text{median} = x_{\frac{n+1}{2}}
# $$
#
# - If $n$ is **even**, the median is the average of the two middle values:
# $$
# \text{median} = \frac{x_{\frac{n}{2}} + x_{\frac{n}{2} + 1}}{2}
# $$
#
# ---
#
# ## 🎲 Mode
# The **mode** is the value (or values) that appear most frequently in the data set.
# If all values occur with the same frequency, the data set is said to have **no mode**.
#
# ---

# %% [markdown]
# ## Dependencies

# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv('data/cars.csv')

# %%
df
# Out:
#       manufacturer_name  model_name transmission   color  odometer_value  \
# 0                Subaru     Outback    automatic  silver          190000
# 1                Subaru     Outback    automatic    blue          290000
# 2                Subaru    Forester    automatic     red          402000
# 3                Subaru     Impreza   mechanical    blue           10000
# 4                Subaru      Legacy    automatic   black          280000
# ...                 ...         ...          ...     ...             ...
# 38526          Chrysler         300    automatic  silver          290000
# 38527          Chrysler  PT Cruiser   mechanical    blue          321000
# 38528          Chrysler         300    automatic    blue          777957
# 38529          Chrysler  PT Cruiser   mechanical   black           20000
# 38530          Chrysler     Voyager    automatic  silver          297729
#
#        year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# ...

# %%
# Mean calculation
df['price_usd'].mean()
# Out:
# np.float64(6639.971021255613)

# %%
# Median calculation
df['price_usd'].median()
# Out:
# 4800.0

# %%
df['price_usd'].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.displot(df, x='price_usd', hue='manufacturer_name')

# %% [markdown]
# This chart is overloaded with information because there are too many manufacturer names. In such cases, it’s best to find a category with the smallest possible number of categories.

# %%
sns.displot(df, x='price_usd', hue='engine_type', multiple='stack')

# %%
df.groupby('engine_type').count()
# Out:
#              manufacturer_name  model_name  transmission  color  \
# engine_type
# diesel                   12874       12874         12874  12874
# electric                    10          10            10     10
# gasoline                 25647       25647         25647  25647
#
#              odometer_value  year_produced  engine_fuel  engine_has_gas  \
# engine_type
# diesel                12874          12874        12874           12874
# electric                 10             10           10              10
# gasoline              25647          25647        25647           25647
#
#              engine_capacity  body_type  ...  feature_1  feature_2  feature_3  \
# engine_type                              ...
# diesel                 12874      12874  ...      12874      12874      12874
# electric                   0         10  ...         10         10         10
# gasoline               25647      25647  ...      25647      25647      25647
#
# ...

# %% [markdown]
# The following chart is likewise difficult to analyze because there is a huge difference between the number of electric and fuel-powered cars.

# %%
Q7_df = df[(df['manufacturer_name']=='Audi') & (df['model_name']=='Q7')]
sns.histplot(Q7_df, x='price_usd', hue='year_produced')
# Out:
# <Axes: xlabel='price_usd', ylabel='Count'>
